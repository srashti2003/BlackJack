# %%
# STEP 1
import random

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
        'Queen':10, 'King':10, 'Ace':11}

playing = True

# %%
# STEP 2
class Card:
    
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
    
    def __str__(self):
        return self.rank + " of " + self.suit

# %%
# STEP 3
from ssl import create_default_context

class Deck:
    
    def __init__(self):
        self.deck = []           # start with an empty list
        for suit in suits:
            for rank in ranks:
                created_card = Card(suit,rank)
                self.deck.append(created_card)

#     def __str__(self):
#         for card in self.deck:
#             print(card)
    def __str__(self):
        deck_comp = ''
        for card in self.deck:
            deck_comp += "\n" + card.__str__()
        return "The deck has:" + deck_comp

    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        return self.deck.pop()

# %%
# Test Step 3
test_check = Deck()

# %%
test_check.shuffle()
print(test_check)
# Out:
# The deck has:
# King of Spades
# Queen of Diamonds
# Nine of Diamonds
# Six of Spades
# Ace of Spades
# Ace of Diamonds
# Three of Clubs
# Ten of Spades
# Two of Spades
# Seven of Diamonds
# Ace of Hearts
# Five of Diamonds
# Eight of Diamonds
# Ace of Clubs
# Three of Hearts
# Ten of Diamonds
# Two of Hearts
# Two of Clubs
# Ten of Clubs
# Six of Hearts
# King of Diamonds
# Nine of Spades
# Jack of Hearts
# King of Hearts
# Eight of Hearts
# Ten of Hearts
# Jack of Spades
# Three of Spades
# Five of Spades
# Three of Diamonds
# Eight of Spades
# Four of Spades
# Five of Hearts
# Seven of Clubs
# Nine of Clubs
# Six of Clubs
# Queen of Spades
# Four of Clubs
# Five of Clubs
# Four of Hearts
# Jack of Clubs
# Four of Diamonds
# Seven of Hearts
# Six of Diamonds
# Nine of Hearts
# Queen of Hearts
# Jack of Diamonds
# King of Clubs
# Eight of Clubs
# Two of Diamonds
# Queen of Clubs
# Seven of Spades

# %%
# STEP 4
class Hand:
    def __init__(self):
        self.cards = []    # start with an empty list as we did in the Deck class
        self.value = 0     # start with zero value
        self.aces = 0      # add an attribute to keep track of aces
             
    def add_card(self,card):
        # card passed in 
        # from Deck.deal() --> single Card(suit,rank)
        self.cards.append(card)
        self.value += values[card.rank]
        
        # track aces
        if card.rank == 'Ace':
            self.aces += 1
    
    def adjust_for_ace(self):
        
        # if total value > 21 and i still have an ace
        # then change my ace into 1 instead of 11.
        while self.value > 21 and self.aces > 1:
            self.value -= 10
            self.aces -= 1

# %%
# Test Step 4
test_deck = Deck()
test_deck.shuffle()

# %%
test_player = Hand()
pulled_card = test_deck.deal()
print(pulled_card)
test_player.add_card(pulled_card)
test_player.value
# Out:
# Five of Clubs
# 5

# %%
# STEP 5
class Chips:
    
    def __init__(self,total=100):
        self.total = total                         # This can be set to a default value or supplied by a user input
        self.bet = 0
        
    def win_bet(self):
        self.total += self.bet
    
    def lose_bet(self):
        self.total -=self.bet

# %%
# STEP 6
def take_bet(chips):
    while True:
        try:
            chips.bet = int(input("\nHow many chips would you like to bet?"))
        except:
            print('\n Please provide an integer for a bet!')
        else:
            if chips.bet > chips.total:
                print('\n You do not have enough chips. You have {}'.format(chips.total))
            else:
                break

# %%
# STEP 7
def hit(deck,hand):
    hand.add_card(deck.deal())
    hand.adjust_for_ace()

# %%
# STEP 8
def hit_or_stand(deck,hand):
    global playing  # to control an upcoming while loop
    
    while True:
        x = input('\nHit or Stand? Enter h or s: ')
        if x[0].lower() == 'h':
            hit(deck,hand)
        elif x[0].lower() == 's':
            print("\nPlayer Stands! Dealer's Turn")
            playing = False
        else:
            print('\nSorry Did not understand please enter h or s!')
            continue
        break

# %%
items = [1,2,3]

# %%
print("Items are: ", *items, sep = '\n')
# Out:
# Items are:
# 1
# 2
# 3

# %%
# STEP 8
def show_some(player,dealer):
    
    # show only one card of dealer
    print("\nDealer's hand: ")
    print("First card hidden!")
    print(dealer.cards[1])
    
    # show all cards (2 cards) 
    print("\nPlayer's hand: ")
    for card in player.cards:
        print(card)
    
def show_all(player,dealer):
    
    # show all cards of dealer
    print("\nDealer's hand: ")
    for card in dealer.cards:
        print(card)
        
    print("\nDealer's hand: ", *dealer.cards, sep = '\n')
    # calculate and display value (J+K=20)
    print(f"\nThe value of dealer's hand is: {dealer.value}")
    
     # show all cards of player
    print("\nPlayer's hand: ")
    for card in player.cards:
        print(card)
    print(f"\nThe value of player's hand is: {player.value}")

# %%
# STEP 9
def player_busts(player,dealer,chips):
    print("\nPLAYER BUSTED!")
    chips.lose_bet()
    
def player_wins(player,dealer,chips):
    print("\nPLAYER WINS!")
    chips.win_bet()
    
def dealer_busts(player,dealer,chips):
    print("\nDEALER BUSTS!")
    chips.lose_bet()
    
def dealer_wins(player,dealer,chips):
    print("\nDEALER WINS!")
    chips.win_bet()
    
def push(player,dealer):
    print("\nPLAYER AND DEALER, TIE. PUSH!")

# %%
# FINAL STEP

while True:
    # Print an opening statement
    print("\nWELCOME TO BLACKJACK CARD GAME!")
    
    # Create & shuffle the deck, deal two cards to each player
    my_deck = Deck()
    my_deck.shuffle()

    player_hand = Hand()
    player_hand.add_card(my_deck.deal())
    player_hand.add_card(my_deck.deal())

    dealer_hand = Hand()
    dealer_hand.add_card(my_deck.deal())
    dealer_hand.add_card(my_deck.deal())
    # Set up the Player's chips
    player_chips = Chips()
    
    # Prompt the Player for their bet
    take_bet(player_chips)
    
    # Show cards (but keep one dealer card hidden)
    show_some(player_hand,dealer_hand)
    
    while playing == True:  # recall this variable from our hit_or_stand function
        
        # Prompt for Player to Hit or Stand
        hit_or_stand(my_deck, player_hand)
        
        # Show cards (but keep one dealer card hidden)
        show_some(player_hand,dealer_hand)
        
        # If player's hand exceeds 21, run player_busts() and break out of loop
        if player_hand.value > 21:
            player_busts(player_hand, dealer_hand, player_chips)

            break

    # If Player hasn't busted, play Dealer's hand until Dealer reaches 17
    if player_hand.value <=21:

        while dealer_hand.value < 17:
            hit(my_deck, dealer_hand)

    
        # Show all cards
        show_all(player_hand,dealer_hand)
        # Run different winning scenarios
        if dealer_hand.value>21:
            dealer_busts(player_hand,dealer_hand,player_chips)
        elif dealer_hand.value > player_hand.value:
            dealer_wins(player_hand,dealer_hand,player_chips)
        elif dealer_hand.value < player_hand.value:
            player_wins(player_hand,dealer_hand,player_chips)
        else:
            push(player_hand,dealer_hand)
    # Inform Player of their chips total 
    print("\nPlayer total chips are at: {}".format(player_chips.total))
    # Ask to play again
    game_play = input("\nWanna play again? y or n: ")
    if game_play[0].lower() == 'y':
        playing = True
        continue
    else:
        playing = False
        print("\nThankyou for playing!")
        break
# Out:
# WELCOME TO BLACKJACK CARD GAME!
#
# How many chips would you like to bet?5
#
# Dealer's hand:
# First card hidden!
# Queen of Diamonds
#
# Player's hand:
# Queen of Spades
# Three of Diamonds
#
# Hit or Stand? Enter h or s: s
#
# Player Stands! Dealer's Turn
#
# Dealer's hand:
# First card hidden!
# Queen of Diamonds
#
# Player's hand:
# Queen of Spades
# Three of Diamonds
#
# Dealer's hand:
# Four of Diamonds
# Queen of Diamonds
# King of Clubs
#
# Dealer's hand:
# Four of Diamonds
# Queen of Diamonds
# King of Clubs
#
# The value of dealer's hand is: 24
#
# Player's hand:
# Queen of Spades
# Three of Diamonds
#
# The value of player's hand is: 13
#
# DEALER BUSTS!
#
# Player total chips are at: 95
